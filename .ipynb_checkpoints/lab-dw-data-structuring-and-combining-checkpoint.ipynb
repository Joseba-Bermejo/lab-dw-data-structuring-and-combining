# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# I will use option 2. I will import the clean file I saved in the previous lab.

import pandas as pd
url = 'https://raw.githubusercontent.com/Joseba-Bermejo/lab-dw-data-cleaning-and-formatting/refs/heads/main/clean_data.csv'
df1 = pd.read_csv ('https://raw.githubusercontent.com/Joseba-Bermejo/lab-dw-data-cleaning-and-formatting/refs/heads/main/clean_data.csv')
df1.drop('Unnamed: 0', axis=1, inplace=True)
df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington      M                Master
# 1     QZ44356     Arizona      F             Bachelors
# 2     AI49188      Nevada      F             Bachelors
# 3     WW63253  California      M             Bachelors
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327  California      F  High School or Below
# 1068  GS98873     Arizona      F             Bachelors
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                7.936903e+05      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %%
# Now I will import the other two datasets

# df2
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
df2 = pd.read_csv ('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')

# %%
# Cleaning and formatting df2

df2.columns = ['customer', 'state','gender', 'education', 'customer_lifetime_value', 'income', 'monthly_premium_auto',
       'number_of_open_complaints', 'total_claim_amount','policy_type',  'vehicle_class']
df.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
df2.head(2)
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
#
#      policy_type  vehicle_class
# 0  Personal Auto  Four-Door Car
# 1   Special Auto            SUV

# %%
df2["gender"].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
gender_mapping = {"F":"F", "M":"M", "Femal":"F", "Male":"M", "female":"F"}
df2["gender"] = df2["gender"].map(gender_mapping)

# %%
df2["education"].unique()
# Out:
# array(['Bachelors', 'Master', 'College', 'Doctor', 'High School or Below'],
#       dtype=object)

# %%
df2['education'] = df2['education'].apply(lambda x: "Bachelors" if x== "Bachelor" else x)

# %%
df2["customer_lifetime_value"] = df2["customer_lifetime_value"].apply(lambda x: x.strip("%") if type(x) == str else x)

# %%
df2["vehicle_class"].unique()
# Out:
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Luxury'], dtype=object)

# %%
cars_to_be_replaced = ["Sports Car", "Luxury SUV", "Luxury Car"]

df2["vehicle_class"] = df2["vehicle_class"].apply(lambda x: "Luxury" if x in cars_to_be_replaced else x)

# %%
df2["customer_lifetime_value"] = df2["customer_lifetime_value"].apply(lambda x: float(x))

# %%
df2["number_of_open_complaints"].unique()
# Out:
# array(['0', '1', '3', '5', '2', '4'], dtype=object)

# %%
df2["number_of_open_complaints"] = df2["number_of_open_complaints"].apply(lambda x: x.split("/")[1])

# %%
df2.isnull().any()
# Out:
# customer                     False
# state                        False
# gender                        True
# education                    False
# customer_lifetime_value       True
# income                       False
# monthly_premium_auto         False
# number_of_open_complaints    False
# total_claim_amount           False
# policy_type                  False
# vehicle_class                False
# dtype: bool

# %%
df2.isnull().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# total_claim_amount           0
# policy_type                  0
# vehicle_class                0
# dtype: int64

# %%
df2 = df2.dropna(subset=['customer_lifetime_value','gender'])
df2
# Out:
#     customer       state gender  education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelors                323912.47   16061
# 1    CW49887  California      F     Master                462680.11   79487
# 2    MY31220  California      F    College                899704.02   54230
# 3    UH35128      Oregon      F    College               2580706.30   71210
# 4    WH52799     Arizona      F    College                380812.21   94903
# ..       ...         ...    ...        ...                      ...     ...
# 991  HV85198     Arizona      M     Master                847141.75   63513
# 992  BS91566     Arizona      F    College                543121.91   58161
# 993  IL40123      Nevada      F    College                568964.41   83640
# 994  MY32149  California      F     Master                368672.38       0
# 995  SA91515  California      M  Bachelors                399258.39       0
#
# ...

# %%
df2.duplicated().any()
# Out:
# False

# %%
#df3
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
df3 = pd.read_csv ('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# Cleaning and formatting df3

df3.columns = df3.columns = ['customer', 'state', 'customer_lifetime_value', 'education', 'gender', 'income', 'monthly_premium_auto',
       'number_of_open_complaints', 'policy_type', 'total_claim_amount', 'vehicle_class']

# %%
df3.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
df3["vehicle_class"].unique()
# Out:
# array(['Two-Door Car', 'Four-Door Car', 'SUV', 'Luxury'], dtype=object)

# %%
df3['education'] = df3['education'].apply(lambda x: "Bachelors" if x== "Bachelor" else x)

# %%
cars_to_be_replaced = ["Sports Car", "Luxury SUV", "Luxury Car"]

df3["vehicle_class"] = df3["vehicle_class"].apply(lambda x: "Luxury" if x in cars_to_be_replaced else x)

# %%
df3.duplicated().any()
# Out:
# False

# %%
df3.isnull().any()
# Out:
# customer                     False
# state                        False
# customer_lifetime_value      False
# education                    False
# gender                       False
# income                       False
# monthly_premium_auto         False
# number_of_open_complaints    False
# policy_type                  False
# total_claim_amount           False
# vehicle_class                False
# dtype: bool

# %%
df1.head(2)
# Out:
#   customer       state gender  education  customer_lifetime_value  income  \
# 0  RB50392  Washington      M     Master            793690.259345     0.0
# 1  QZ44356     Arizona      F  Bachelors            697953.590000     0.0
#
#    monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0                1000.0                        1.0  Personal Auto
# 1                  94.0                        1.0  Personal Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935

# %%
df2.head(2)
# Out:
#   customer       state gender  education  customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelors                323912.47   16061
# 1  CW49887  California      F     Master                462680.11   79487
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                         0               633.6
# 1                   114                         0               547.2
#
#      policy_type  vehicle_class
# 0  Personal Auto  Four-Door Car
# 1   Special Auto            SUV

# %%
df3.head(2)
# Out:
#   customer       state  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
#
#    total_claim_amount vehicle_class
# 0          499.200000  Two-Door Car
# 1            3.468912  Two-Door Car

# %%
# since they are all clean, I will concatenate them now.

# %%
df_final = pd.concat([df1, df2, df3], axis=0)

# %%
df_final
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington      M                Master
# 1     QZ44356     Arizona      F             Bachelors
# 2     AI49188      Nevada      F             Bachelors
# 3     WW63253  California      M             Bachelors
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M             Bachelors
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M             Bachelors
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                7.936903e+05      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
import pandas as pd
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
df_markt = pd.read_csv ('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')
df_markt.drop('unnamed:_0', axis=1, inplace=True)
df_markt
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
df_markt.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
pivot_markt = df_markt.pivot_table(index='sales_channel', values=['customer_lifetime_value'], aggfunc="sum").round(2)

# %%
pivot_markt
# Out:
#                customer_lifetime_value
# sales_channel
# Agent                      33057887.85
# Branch                     24359201.21
# Call Center                17364288.37
# Web                        12697632.90

# %% [markdown]
# The channel bringing more value to the business is "Agent", almost 3 times higher than the lowest value which is "Web".

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_markt2 = df_markt.pivot_table(index='gender', columns='education', values=['customer_lifetime_value'], aggfunc="sum").round(2)

# %%
pivot_markt2
# Out:
#           customer_lifetime_value                           \
# education                Bachelor      College      Doctor
# gender
# F                     13386258.11  12460107.91  1465701.78
# M                     12110061.83  12851725.02  1490482.06
#
#
# education High School or Below      Master
# gender
# F                  13793600.12  3874600.25
# M                  12680914.19  3365559.06

# %% [markdown]
# Customers with a Master’s degree generate the highest lifetime value overall. While customer value is fairly consistent across genders within most education levels, females with a Master’s degree contribute more (around 15%) than their male counterparts.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
